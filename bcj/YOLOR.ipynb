# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/WongKinYiu/yolor
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 461, done.
# remote: Counting objects: 100% (251/251), done.
# remote: Compressing objects: 100% (201/201), done.
# remote: Total 461 (delta 147), reused 52 (delta 46), pack-reused 210
# Receiving objects: 100% (461/461), 3.20 MiB | 25.02 MiB/s, done.
# Resolving deltas: 100% (208/208), done.

# %%
# %cd yolor

# pip install required packages
# !pip install -qr requirements.txt
# Out:
# /content/yolor
#      |████████████████████████████████| 636 kB 5.2 MB/s
#      |████████████████████████████████| 776.7 MB 4.3 kB/s
#      |████████████████████████████████| 12.7 MB 24.3 MB/s
#      |████████████████████████████████| 1.5 MB 42.1 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.7.0 which is incompatible.

# %%
#!bash scripts/get_coco.sh

# %%
# %%time
# Train YOLOR (based on yolov5)
# NOTE:  the code starts printing P/R/MAP after the 3rd epoch
# !python train.py --img 640 640 --batch 16 --epochs 100 --project /content/drive/MyDrive/yolor --data df2.yaml --cfg cfg/yolor_p6.cfg --weights '' --device 0
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='cfg/yolor_p6.cfg', data='./data/df2.yaml', device='0', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='/content/drive/MyDrive/yolor', rect=False, resume=False, save_dir='/content/drive/MyDrive/yolor/exp5', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir /content/drive/MyDrive/yolor", view at http://localhost:6006/
# ...
